# %% [markdown]
# <a href="https://colab.research.google.com/github/A109010162/Computational-Thinking-and-program-design/blob/main/%E6%9C%9F%E6%9C%AB%E5%88%86%E7%B5%84%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **題目：「你的聊天好朋友」，現代人沒時間交朋友，因此打造出陪伴人類的機器人，打造出不尷尬又自然輕鬆的聊天空間，最近疫情下的我們每天居家防疫，於是新版本新增了遊戲功能，使我們在家也能有人(機器人)陪伴。**

# %% [markdown]
# 成員
# A109010087 陳盈臻
# A109010096 劉宇珊
# A109010135 劉庭宇
# A109010162 王詩婷

# %% [markdown]
# 腳本：
#
# 人：Hi 我是__(名字)＿
# 人：就讀＿(學校)__，目前在補習班工作
# 機：哇塞
# 人：欸你千萬不要去那兒，因為老闆＿__(形容詞)__
# 機：真的嗎
# 人：對啊，話說回來我剛剛吃了__(食物)＿，還喝了＿(飲料)__
# 機：我覺得那很難吃
# 人：我最喜歡吃的是＿(食物2)__
# 機：我同意，尤其是＿（地名）__那間
# 人：哇!我家人也喜歡吃個連狗狗都喜歡
# 我家狗狗的名字叫做＿_(狗名)＿
# 有機會的話也可以帶你來我家看__（狗名）__
# 機：好呀呀，問你唷，你最愛的明星是誰啊？
# 人：__(明星)____，因為他¬¬_____(原因)___！
# 機：我也超愛__(明星)__的欸， 我也覺得他___(原因)__，還有他香香腿又長……。
# 機：那你以後想做什麼工作呀？
# 人：我想當一名___(工作)__！
# 機：我也覺得你很適合當__(工作)___，那你想知道我以後想做什麼嗎？
# 人：___(輸入想或不想)____
#
# 機(IF不想)：喔喔是喔我還是想跟你說.......我想要把全世界都變成我的天下，所有工作都由機器人服務，包括__(工作)____。
# 你們人類可以休息了唷~~
# 啥款？
#
# 機(IF想)：我想要把全世界都變成我的天下，所有工作都由機器人服務，包括__(工作)____。
# 你們人類可以休息了唷~~
# 啥款？
#
# 人：(請隨意回覆以上對話)
# 機：那你今天心情怎麼樣勒？
# 人：我今天很__（輸入開心OR不開心）___
#
# 機(IF不開心)：蛤為什麼會不開心！
# 人：是因為__（事件）___啊⋯⋯
# 機：啊真的假的！怎麼會......如果是我遇到__（事件）___我應該也會__（心情）___！
# 機：那我們來玩個遊戲讓你心情比較好點
#
# 機(IF開心)：今天遇到什麼好事呀
# 人：對呀，今天遇到___(事件)__
# 機：啊真的假的！好好喔~~~好好喔~~~
# 機：那趁你的好心情我們來玩個遊戲吧！！
#
# (開始玩黑白切的遊戲)
#
# 機：有其他事情也可以跟我分享喔！我會傾聽的
# 人：那你知道的可能就太多了耶
# 機：蛤？
# 人：好啊好啊
# 機：那我可以跟你要賴嗎？方便以後聯絡
# 人：可以啊！兩次π到小數點後五位相加就是了！
# 機：（計算後輸入）好的，我加你好友了！
# 人：那今天先這樣啦，保持聯絡！
#
# 請人類為此次服務打分數，並說明應改進的地方

# %%
name = input("：嗨我是")
school = input("：就讀")  
print(f"：目前在補習班打工")
print(f"哇賽")
print(f"：欸你千萬不要去那裏工作，")

Adj = input("：因為老闆很")


food = input("：話說回來我剛剛吃了")
drink = input("：還喝了")

print(f"我覺得那很難吃")
the_other_food = input("：我最喜歡吃") 
where = ("中正路")
print(f"我同意，尤其是{where}那間")
print(f"：哇！我家人也喜歡吃那個連狗狗也喜歡")
dog_name = input("：我家狗狗的名字叫")
print(f"：有機會的話也可以帶你來我家看{dog_name}")
print("好呀呀，問你唷，你最愛的明星是誰啊？")
idol = input(":")
why = input("：因為......")
print(f"我也超愛{idol}的欸，我也覺得{why}，還有他香香腿又長......。")
print("那你以後想做什麼工作呀？")
work = input("：我想當一名")
print(f"我也覺得你很適合當{work}，那你想知道我以後要做什麼嗎？")
want= input("：請輸入「想知道」或「不想知道」：")
if want == "想知道" :
    print(f"我想把全世界都變成我的天下，所有工作都由機器人服務，包括{work}")
    print("你們人類可以休息了唷~~")
    print("啥款")

else:
    print("喔喔是喔可是我還是想跟你說......")
    print(f"我想要把全世界都變成我的天下，所有工作都由機器人服務，包括{work}。")
    print("你們人類可以休息了唷~~")
    print("啥款")

respond = input("請隨意回復以上對話：")
print("那你今天心情怎麼樣勒？")
mood= input("：請輸入開心或不開心：")
if mood == "開心" :
    print("今天是不是遇到什麼好事呀 ")
    things= input("：對呀，我今天 ")
    print("啊真的假的！好好喔")
    print("那趁你的好心情我們來玩個遊戲吧！！")

else: 
    print("蛤為什麼會不開心！")
    things= input("：是因為我 ")
    print(f"啊真的假的！怎麼會......如果是我{things} 我應該也會{mood}！ ")
    print("那我們來玩個遊戲讓你心情比較好點")

my_choice = int(input("請出拳 [0] 剪刀 [1] 石頭 [2] 布 "))
print("你出的拳:", my_choice)
import random
com_choice = random.randint(0, 2)
print("電腦出拳為", com_choice)

if my_choice == (com_choice + 1)%3 :
  print("你猜拳贏了")
  m_c=int(input("手指方向 [0] 上 [1] 下 [2] 左 [3]右"))
  import random
  c_c = random.randint(0, 3)
  print("電腦頭擺", c_c)
  if m_c == c_c :
    print("你贏了")
  else:
    print("我們平手")
elif my_choice == com_choice:
  print("我們平手")
else:
  print('電腦猜拳贏了')
  m_c=int(input("頭擺方向 [0] 上 [1] 下 [2] 左 [3]右"))
  import random
  c_c = random.randint(0, 3)
  print("電腦手指方向", c_c)
  if m_c == c_c :
    print("你輸了")
  else:
    print("我們平手")

a=input("：玩完了耶，我覺得 ")
print("那我可以跟你要LINE嗎?方便以後聯絡")
print("：可以啊!兩次π到小數點後五位相加就是我的ID了!")
print(3.14159+3.14159)
print("好的，我加你好友了!")
print("：那今天先這樣啦，保持聯絡!")
point=int(input("感謝您的使用，請問我們此次的服務1~10分您給幾分呢？"))
if point >=5  :
    print("感謝您的支持，我們會繼續努力的！！")
    
else:
    why=input("真假!!!怎麼了嗎，麻煩您跟我們說明一下：")
    print(f"已收到您「{why}」的需求，我們會積極改進這項缺失，希望下次能讓您看到我們的改變。")
# Out:
# ：嗨我是下輩子要嫁給李壽根的人
# ：就讀彰化葡萄大學
# ：目前在補習班打工
# 哇賽
# ：欸你千萬不要去那裏工作，
# ：因為老闆很傻不隆冬
# ：話說回來我剛剛吃了維他命
# ：還喝了維他命
# 我覺得那很難吃
# ：我最喜歡吃補品
# 我同意，尤其是中正路那間
# ：哇！我家人也喜歡吃那個連狗狗也喜歡
# ：我家狗狗的名字叫待商榷
# ：有機會的話也可以帶你來我家看待商榷
# 好呀呀，問你唷，你最愛的明星是誰啊？
# :林黛玉
# ：因為......名字很酷 黑玉
# 我也超愛林黛玉的欸，我也覺得名字很酷 黑玉，還有他香香腿又長......。
# 那你以後想做什麼工作呀？
# ：我想當一名米蟲
# 我也覺得你很適合當米蟲，那你想知道我以後要做什麼嗎？
# ：請輸入「想知道」或「不想知道」：想知道
# 我想把全世界都變成我的天下，所有工作都由機器人服務，包括米蟲
# 你們人類可以休息了唷~~
# 啥款
# 請隨意回復以上對話：可以ㄟ
# 那你今天心情怎麼樣勒？
# ：請輸入開心或不開心：不開心
# 蛤為什麼會不開心！
# ：是因為我 沒有到很開心
# 啊真的假的！怎麼會......如果是我沒有到很開心 我應該也會不開心！
# 那我們來玩個遊戲讓你心情比較好點
# 請出拳 [0] 剪刀 [1] 石頭 [2] 布 0
# 你出的拳: 0
# 電腦出拳為 1
# 電腦猜拳贏了
# 頭擺方向 [0] 上 [1] 下 [2] 左 [3]右2
# 電腦手指方向 0
# 我們平手
# ：玩完了耶，我覺得 好強喔 我居然沒有輸
# 那我可以跟你要LINE嗎?方便以後聯絡
# ：可以啊!兩次π到小數點後五位相加就是我的ID了!
# 6.28318
# 好的，我加你好友了!
# ：那今天先這樣啦，保持聯絡!
# 感謝您的使用，請問我們此次的服務1~10分您給幾分呢？10
# 感謝您的支持，我們會繼續努力的！！
